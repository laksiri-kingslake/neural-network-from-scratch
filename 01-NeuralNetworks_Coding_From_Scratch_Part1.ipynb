# %% [markdown]
# <a href="https://colab.research.google.com/github/laksiri-kingslake/neural-network-from-scratch/blob/main/NeuralNetworks_Coding_From_Scratch_Part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## BUILDING NEURAL NETWORKS FROM SCRATCH PART 1: CODING NEURONS AND LAYERS

# %% [markdown]
# ### CODING OUR FIRST NEURON: 3 INPUTS

# %% [markdown]
# ![Neuron with 3 inputs](./images/neuron-3-input.png)

# %%
inputs = [1, 2, 3]
weights = [0.2, 0.8, -0.5]
bias = 2

outputs = (inputs[0]*weights[0] + inputs[1]*weights[1] + inputs[2]*weights[2] + bias)

print(outputs)
# Out:
# 2.3

# %%
import numpy as np
X = np.array(inputs)
W = np.array(weights)
outputs = np.dot(X, W.transpose()) + bias
print(outputs)

# print dimensions of X and W
print("Dimensions of X:", X.shape)
print("Dimensions of W:", W.shape)
# Out:
# 2.3
# Dimensions of X: (3,)
# Dimensions of W: (3,)

# %% [markdown]
# ### CODING OUR SECOND NEURON: 4 INPUTS ###

# %% [markdown]
# ![Neuron with 4 inputs](./images/neuron-4-input.png)

# %%
inputs = [1.0, 2.0, 3.0, 2.5]
weights = [0.2, 0.8, -0.5, 1.0]
bias = 2.0
output = (inputs[0]*weights[0] +
 inputs[1]*weights[1] +
 inputs[2]*weights[2] +
 inputs[3]*weights[3] + bias)

print(output)
# Out:
# 4.8

# %%
output = np.dot(inputs, weights) + bias
print(output)
# Out:
# 4.8

# %% [markdown]
# ### CODING OUR FIRST LAYER

# %% [markdown]
# ![A layer of neurons](./images/neuron-layer.png)

# %%
inputs = [1, 2, 3, 2.5]

weights = [[0.2, 0.8, -0.5, 1],
 [0.5, -0.91, 0.26, -0.5],
 [-0.26, -0.27, 0.17, 0.87]]

weights1 = weights[0] #LIST OF WEIGHTS ASSOCIATED WITH 1ST NEURON : W11, W12, W13, W14
weights2 = weights[1] #LIST OF WEIGHTS ASSOCIATED WITH 2ND NEURON : W21, W22, W23, W24
weights3 = weights[2] #LIST OF WEIGHTS ASSOCIATED WITH 3RD NEURON : W31, W32, W33, W34

biases = [bias1, bias2, bias3] = [2, 3, 0.5]

outputs = [
 # Neuron 1:
 inputs[0]*weights1[0] +
 inputs[1]*weights1[1] +
 inputs[2]*weights1[2] +
 inputs[3]*weights1[3] + bias1,
 # Neuron 2:
 inputs[0]*weights2[0] +
 inputs[1]*weights2[1] +
 inputs[2]*weights2[2] +
 inputs[3]*weights2[3] + bias2,
 # Neuron 3:
 inputs[0]*weights3[0] +
 inputs[1]*weights3[1] +
 inputs[2]*weights3[2] +
 inputs[3]*weights3[3] + bias3]

print(outputs)
# Out:
# [4.8, 1.21, 2.385]

# %%
X = np.array(inputs)
W = np.array(weights)

outputs = np.dot(X, W.transpose()) + biases
print(outputs)
# Out:
# [4.8   1.21  2.385]

# %%
# shape of X and W
print("Shape of X:", X.shape)
print("Shape of W:", W.shape)
# Out:
# Shape of X: (4,)
# Shape of W: (3, 4)

# %% [markdown]
# ### USING LOOPS FOR BETTER AND EASIER CODING

# %%
inputs = [1, 2, 3, 2.5]

##LIST OF WEIGHTS
weights = [[0.2, 0.8, -0.5, 1],
 [0.5, -0.91, 0.26, -0.5],
 [-0.26, -0.27, 0.17, 0.87]]

##LIST OF BIASES
biases = [2, 3, 0.5]

# Output of current layer
layer_outputs = []

# For each neuron
for neuron_weights, neuron_bias in zip(weights, biases):
  # Zeroed output of given neuron
  neuron_output = 0
  # For each input and weight to the neuron
  for n_input, weight in zip(inputs, neuron_weights):
    # Multiply this input by associated weight
    # and add to the neuron's output variable
    neuron_output += n_input*weight ## W31*X1 + W32*X2 + W33*X3 + W34*X4
  # Add bias
  neuron_output += neuron_bias ## ## W31*X1 + W32*X2 + W33*X3 + W34*X4 + B3
  # Put neuron's result to the layer's output list
  layer_outputs.append(neuron_output)
print(layer_outputs)
# Out:
# [4.8, 1.21, 2.385]

# %% [markdown]
# ### USING NUMPY

# %% [markdown]
# #### NumPy dot Product
#
# 1. NumPy dot Product of Vectors
#
#     x = [a1, a2, a3]
#
#     y = [b1, b2, b3]
#
#     np.dot(x, y) = a1*b1 + a2*b2 + a3*b3

# %%
import numpy as np
x = np.array([1, 2, 3])
y = np.array([4, 5, 6])
print(np.dot(x, y))  # Output: 32
# Out:
# 32

# %% [markdown]
# 2. NumPy dot product of vector and matrix
#
#     x = [a1, a2, a3] # 1 x 3
#
#     y = [[b11, b12, b13],<br>
#          [b21, b22, b23],<br>
#          [b31, b32, b33]] # 3 x 3
#
#     np.dot(x, y) = [a1*b11 + a2*b21 + a3*b31, a1*b12 + a2*b22 + a3*b32, a1*b13 + a2*b23 + a3*b33] # 1 x 3
#
#     Let's call<br>
#     bn1 = [b11,b21,b31]<br>
#     bn2 = [b12,b22,b32]<br>
#     bn3 = [b13,b23,b33]<br>
#     Then,<br>
#     np.dot(x, y) = [np.dot(x,bn1), np.dot(x,bn2), np.dot(x,bn3)] # 1 x 3
#
#     np.dot(y, x) = [[np.dot(bn1, x)],[np.dot(bn2, x)],[np.dot(bn3, x)]]

# %%
y = np.array([[4, 5, 6],[7, 8, 9],[10, 11, 12]]) # 3 x 3 matrix
print(np.dot(x, y))  # Output: 48 54 60 1 x 3 matrix (vector)
# Out:
# [48 54 60]

# %%
print(np.dot(y, x)) # Output: [32  50  48] 3 x 1 matrix (vector)
# Out:
# [32 50 68]

# %% [markdown]
# 3. NumPy dot product of a matrix and a matrix
#
#     a = [[a11, a12],<br>
#          [a21, a22],<br>
#          [a31, a32]]<br> # 3 x 2 matrix
#
#     y = [[b11, b12, b13],<br>
#          [b21, b22, b23]] # 2 x 3 matrix<br>
#
#     Let's call<br>
#     a1 = [a11, a12]<br>
#     a2 = [a21, a22]<br>
#     a3 = [a31, a32]<br>
#     bn1 = [b11,b21]<br>
#     bn2 = [b12,b22]<br>
#     bn3 = [b13,b23]<br>
#     Then,<br>
#
#     np.dot(a, b) = [[np.dot(a1,bn1), np.dot(a1,bn2), np.dot(a1,bn3)],<br>
#                     [np.dot(a2,bn1), np.dot(a2,bn2), np.dot(a2,bn3)],<br>
#                     [np.dot(a3,bn1), np.dot(a3,bn2), np.dot(a3,bn3)]]     # 3 x 3 matrix

# %%
import numpy as np

a = np.array([[1, 2],
              [3, 4],
              [5, 6]]) # 3 x 2 matrix

b = np.array([[7, 8, 9],
              [10, 11, 12]]) # 2 x 3 matrix

print(np.dot(a, b)) # Output: [[27 30 33] [61 68 75] [95 106 117]] 3 x 3 matrix
# Out:
# [[ 27  30  33]
#  [ 61  68  75]
#  [ 95 106 117]]

# %% [markdown]
# ### SINGLE NEURON USING NUMPY

# %% [markdown]
# ![A neuron with np dot product](./images/neuron-np-dot.png)

# %%
import numpy as np
inputs = [1.0, 2.0, 3.0, 2.5]
weights = [0.2, 0.8, -0.5, 1.0]
bias = 2.0
outputs = np.dot(weights, inputs) + bias
print(outputs)
# Out:
# 4.8

# %% [markdown]
# ### LAYER OF NEURONS USING NUMPY

# %% [markdown]
# ![A neuron layer with np dot product](./images/neuron-layer-np-dot.png)

# %%
##  In plain Python, we wrote this as a list of lists. With NumPy, this will be a 2-dimensional array, which we’ll call a matrix.

# %%
import numpy as np

inputs = [1.0, 2.0, 3.0, 2.5]
weights = [[0.2, 0.8, -0.5, 1],
 [0.5, -0.91, 0.26, -0.5],
 [-0.26, -0.27, 0.17, 0.87]]
biases = [2.0, 3.0, 0.5]

# A dot product of a matrix and a vector results in a list of dot products.
#The np.dot() method treats the matrix as a list of vectors and performs a dot product of each of those vectors with the other vector

layer_outputs = np.dot(weights, inputs) + biases
print(layer_outputs)

new_outputs = np.dot(inputs, np.transpose(weights)) + np.transpose(biases)
print(new_outputs)
# Out:
# [4.8   1.21  2.385]
# [4.8   1.21  2.385]

# %% [markdown]
# ### LAYER OF NEURONS AND BATCH OF DATA USING NUMPY

# %% [markdown]
# ![A neuron layer with a batch of input](./images/neuron-layer-with-input-batch.png)

# %% [markdown]
# ###### NEED TO TAKE TRANSPOSE OF WEIGHT MATRIX

# %% [markdown]
# ![Get transpose of weights matrix](./images/neuron-layer-with-input-batch-weights-transpose.png)

# %%
inputs = [[1.0, 2.0, 3.0, 2.5], [2.0, 5.0, -1.0, 2.0], [-1.5, 2.7, 3.3, -0.8]]
weights = [[0.2, 0.8, -0.5, 1],
 [0.5, -0.91, 0.26, -0.5],
 [-0.26, -0.27, 0.17, 0.87]]
biases = [2.0, 3.0, 0.5]

# NOTE: WE CAN'T TRANSPOSE LISTS IN PYTHON, SO WE HAVE THE CONVERT THE WEIGHTS MATRIX INTO AN ARRAY FIRST
outputs = np.dot(inputs, np.array(weights).T) + biases
print(outputs)
# Out:
# [[ 4.8    1.21   2.385]
#  [ 8.9   -1.81   0.2  ]
#  [ 1.41   1.051  0.026]]

# %% [markdown]
# ### MULTIPLE LAYERS WITH A BATCH OF DATA USING NUMPY

# %% [markdown]
# ![Multiple layers with a batch of data](./images/multiple-neuron-layers.png)

# %%
import numpy as np

inputs = [[1.0, 2.0, 3.0, 2.5],
          [2.0, 5.0, -1.0, 2.0],
          [-1.5, 2.7, 3.3, -0.8]]

weights = [[0.2, 0.8, -0.5, 1],
           [0.5, -0.91, 0.26, -0.5],
           [-0.26, -0.27, 0.17, 0.87]]

biases = [2, 3, 0.5]

weights2 = [[0.1, -0.14, 0.5],
            [-0.5, 0.12, -0.33],
            [-0.44, 0.73, -0.13]]

biases2 = [-1, 2, -0.5]

# convert lists to numpy arrays
inputs_array = np.array(inputs)
weights_array = np.array(weights)
biases_array = np.array(biases)
weights2_array = np.array(weights2)
biases2_array = np.array(biases2)

# output of the first layer
layer1_outputs = np.dot(inputs_array, weights_array.T) + biases_array

# output of the second layer
layer2_outputs = np.dot(layer1_outputs, weights2_array.T) + biases2_array

# print(layer2_outputs)

weights3 = [[0.1, -0.14, 0.5],
            [-0.5, 0.12, -0.33]]

biases3 = [1, -1]

weights3_array = np.array(weights3)
biases3_array = np.array(biases3)

layer3_outputs = np.dot(layer2_outputs, weights3_array.T) + biases3_array
print(layer3_outputs)
# Out:
# [[ 0.176794  -0.7037845]
#  [-1.474662   0.452205 ]
#  [ 0.5246554 -0.2162637]]

# %% [markdown]
# ## Dense Layer Class

# %% [markdown]
# We write python class named `Layer_Dense` to encapsulate the functionality.
#
# The class has two main methods `__init__` and `forward`

# %% [markdown]
# ![Dense Layer Class - Inputs and Neurons](./images/dense_layer_class_inputs_and_neurons.png)

# %% [markdown]
# Here we take 2 inputs and 3 neurons in the neural network
#
# For wight matrix we already consider transpose so that it is not required to take transpose at the time of evaluation

# %% [markdown]
# #### Matrix calculations for the exercise

# %%
import numpy as np

x1 = np.array([[1, 2, 3]])
print(x1.shape) # Output: (1, 3)

x2 = np.array([[1], [2], [3]])
print(x2.shape) # Output: (3, 1)

x3 = np.random.randn(2, 3)
print(x3.shape) # Output: (2, 3)
print(x3)

x4 = np.zeros((1, 3))
print(x4.shape) # Output: (1, 3)
print(x4)

x4 = np.random.rand(100, 2)
x5 = np.random.rand(2, 3)
x6 = np.random.rand(1, 3)
x7 = np.dot(x4, x5) + x6
print(x7.shape) # Output: (100, 3)
print(x7)
# Out:
# (1, 3)
# (3, 1)
# (2, 3)
# [[-1.1268258  -0.7306777  -0.3848798 ]
#  [ 0.09435159 -0.04217145 -0.2868872 ]]
# (1, 3)
# [[0. 0. 0.]]
# (100, 3)
# [[0.54983665 1.15726566 0.5245564 ]
#  [0.69883578 1.17843239 0.54019992]
#  [0.52857816 1.02387966 0.37251366]
#  [0.72171454 1.38022663 0.77075996]
#  [1.68284251 1.71460275 1.09901695]
#  [0.85019837 1.15017238 0.49890678]
#  [1.18553783 1.37429766 0.73692541]
#  [1.37989761 1.16990082 0.49071877]
#  [1.25641449 1.27424361 0.6178187 ]
#  [0.85905059 1.42305078 0.8119707 ]
#  [0.86471002 1.42565317 0.81463154]
#  [1.04493006 1.31895535 0.68152   ]
#  [1.03414889 1.24295039 0.59480657]
#  [1.22544147 1.33875449 0.69375612]
#  [1.03171785 1.53714751 0.93302636]
#  [1.31072982 1.14989661 0.47176039]
#  [0.74269845 1.23630393 0.60414799]
#  [1.52658619 1.69047861 1.08039771]
#  [1.64838947 1.66342585 1.04221396]
#  [1.02571119 1.62515561 1.03451132]
#  [0.67568462 1.09515385 0.44584868]
#  [1.40030481 1.26413022 0.5978141 ]
#  [1.0867116  1.12581046 0.45713243]
#  [1.40918078 1.61790375 1.00383775]
#  [0.79182003 1.25966464 0.62813135]
#  [1.01763655 1.49177788 0.88170992]
#  [0.6870601  1.13258067 0.4881952 ]
#  [0.9378434  1.23918024 0.59608461]
#  [1.29332306 1.25177072 0.58984363]
#  [1.20849796 1.62340884 1.02185522]
#  [1.31036754 1.59646969 0.98496323]
#  [1.56753077 1.56846128 0.93779557]
#  [1.40858127 1.66472261 1.05767475]
#  [1.51746823 1.39900903 0.74598514]
#  [0.56657846 1.18178396 0.5517564 ]
#  [0.68847738 1.2663538  0.64183872]
#  [0.73212127 1.37384705 0.76282256]
#  [1.07623763 1.57955681 0.97916763]
#  [1.52429117 1.45164366 0.806073  ]
#  [0.86733831 1.38597439 0.76888137]
#  [1.4072267  1.35933165 0.70681207]
#  [1.02632852 1.23350109 0.58440347]
#  [0.97720756 1.29747571 0.66078191]
#  [0.81205077 1.33140679 0.70939561]
#  [0.82657646 1.26116867 0.6278349 ]
#  [1.16448535 1.5129516  0.89748679]
#  [1.0382721  1.58998375 0.99336158]
#  [1.25085129 1.14312257 0.46746434]
#  [0.79661445 1.296802   0.67052864]
#  [0.61846122 1.21919817 0.59172856]
#  [1.34919979 1.50023852 0.87211649]
#  [1.24526651 1.50227003 0.88050585]
#  [0.71347021 1.22857568 0.59696977]
#  [1.35546775 1.60916679 0.99692683]
#  [1.02196957 1.23890918 0.59087214]
#  [0.67052366 1.42314075 0.82305722]
#  [0.53288312 1.22059339 0.59831748]
#  [1.22878523 1.61506526 1.01108526]
#  [0.62350787 1.25114293 0.62814404]
#  [0.53850234 1.20501465 0.58008771]
#  [1.0969577  1.24724482 0.59608245]
#  [0.64054929 1.09565063 0.44846647]
#  [1.19611765 1.48721455 0.86606805]
#  [1.37521793 1.64974599 1.04240798]
#  [0.62212218 1.38214935 0.77877148]
#  [1.18210192 1.42735495 0.79809665]
#  [1.33741285 1.13772114 0.45621438]
#  [1.3525991  1.57312219 0.95567309]
#  [1.0067022  1.2646886  0.62138613]
#  [1.19815458 1.16228044 0.49254971]
#  [1.00479688 1.36556883 0.73742415]
#  [1.10194649 1.14559506 0.47898046]
#  [0.75919007 1.27216937 0.64440216]
#  [1.30673529 1.60666774 0.99689405]
#  [1.04365321 1.16073312 0.49977248]
#  [1.64826764 1.64537488 1.02147769]
#  [1.20187075 1.61149321 1.00854843]
#  [1.23971905 1.61721824 1.01292245]
#  [1.53516842 1.68230234 1.07050197]
#  [1.30227388 1.14331025 0.46468425]
#  [0.70049749 1.25258853 0.62532004]
#  [1.42433263 1.30365653 0.64183618]
#  [0.85733928 1.5445206  0.95165806]
#  [1.14223667 1.5954235  0.99355595]
#  [0.77978168 1.41139729 0.80319704]
#  [0.85079487 1.10323228 0.44493055]
#  [1.15812452 1.23843296 0.58239282]
#  [0.45628774 1.03999296 0.39524181]
#  [0.76824106 1.54392289 0.95616185]
#  [1.42369665 1.62878667 1.01549827]
#  [1.23162724 1.40164472 0.76566638]
#  [1.03541203 1.62972568 1.03919785]
#  [0.91037591 1.32577448 0.69719504]
#  [1.10070278 1.62867759 1.03418975]
#  [0.67938997 1.21643405 0.58500259]
#  [1.07923581 1.12742074 0.45941841]
#  [1.15060832 1.36261095 0.72553046]
#  [0.75474609 1.17808345 0.53654175]
#  [1.02293141 1.28538938 0.64422907]
#  [0.95619334 1.25965397 0.61854308]]

# %% [markdown]
# #### Implementation

# %%
# %%capture
# !pip install nnfs

# %%
import numpy as np
import nnfs
from nnfs.datasets import spiral_data

nnfs.init()

class Layer_Dense:
    def __init__(self, n_inputs, n_neurons):
        # Initialize weights and biases
        self.weights = 0.01 * np.random.randn(n_inputs, n_neurons) 
        self.biases = np.zeros((1, n_neurons))

    # Forward pass
    def forward(self, inputs):
        # Calculate output values from inputs, weights and biases
        self.output = np.dot(inputs, self.weights) + self.biases

# Create dataset
X, y = spiral_data(samples=100, classes=3)

# Create Dense layer with 2 input features and 3 output values
dense1 = Layer_Dense(2, 3)

# Perform a forward pass of our training data through this layer
dense1.forward(X)

print(dense1.output[:5])
# Out:
# [[ 0.0000000e+00  0.0000000e+00  0.0000000e+00]
#  [-1.0475188e-04  1.1395361e-04 -4.7983500e-05]
#  [-2.7414842e-04  3.1729150e-04 -8.6921798e-05]
#  [-4.2188365e-04  5.2666257e-04 -5.5912682e-05]
#  [-5.7707680e-04  7.1401405e-04 -8.9430439e-05]]

# %% [markdown]
# Note the shape of the matrixes
#
# ```
# X --> (100, 2)
# W --> (2, 3) --> input, neurons
# b --> (1, 3)
# ```
#
# `y = np.dot(X, W) + b --> (100, 2) x (2, 3) + (1, 3) --> (100, 3) + (1, 3) --> (100, 3)`

# %% [markdown]
# ### Activation Function

# %% [markdown]
# #### Sigmoid Activation Function

# %% [markdown]
# $$ \sigma(x) = \frac{1}{1 + e^{-x}} $$
# <img src="./images/sigmoid.jpg" width="250">
